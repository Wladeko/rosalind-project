# %%
with open('rosalind_hamm.txt') as f:
    s = f.read().split('\n')

print(s)
# Out:
# ['...', '...', '']

# %%
hd = 0

for i in range(len(s[0])):
    if s[1][i] != s[0][i]:
        hd += 1

print(hd)
# Out:
# 486
